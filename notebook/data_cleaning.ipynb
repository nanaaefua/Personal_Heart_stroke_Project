# %%
import json
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

# from config import db_password

import time

# %%
stroke = pd.read_csv("../Personal_Project/healthcare-dataset-stroke-data.csv")

# %%
heart = pd.read_csv("../Personal_Project/heart.csv")

# %%
stroke_df = pd.DataFrame(stroke)

# %%
stroke_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
stroke_df.tail(10)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5100  68398    Male  82.0             1              0          Yes
# 5101  36901  Female  45.0             0              0          Yes
# 5102  45010  Female  57.0             0              0          Yes
# 5103  22127  Female  18.0             0              0           No
# 5104  14180  Female  13.0             0              0           No
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5100  Self-employed          Rural              71.97  28.3     never smoked
# ...

# %%
stroke_df.notnull().sum()
# Out:
# id                   5110
# gender               5110
# age                  5110
# hypertension         5110
# heart_disease        5110
# ever_married         5110
# work_type            5110
# Residence_type       5110
# avg_glucose_level    5110
# bmi                  4909
# smoking_status       5110
# stroke               5110
# dtype: int64

# %%
stroke_df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
heart_df = pd.DataFrame(heart)

# %%
heart_df.notnull().sum()
# Out:
# Age               918
# Sex               918
# ChestPainType     918
# RestingBP         918
# Cholesterol       918
# FastingBS         918
# RestingECG        918
# MaxHR             918
# ExerciseAngina    918
# Oldpeak           918
# ST_Slope          918
# HeartDisease      918
# dtype: int64

# %%
heart_df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
heart_df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
stroke_df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
stroke_df.notnull().sum()
# Out:
# id                   5110
# gender               5110
# age                  5110
# hypertension         5110
# heart_disease        5110
# ever_married         5110
# work_type            5110
# Residence_type       5110
# avg_glucose_level    5110
# bmi                  4909
# smoking_status       5110
# stroke               5110
# dtype: int64

# %%
heart_df.notnull().sum()
# Out:
# Age               918
# Sex               918
# ChestPainType     918
# RestingBP         918
# Cholesterol       918
# FastingBS         918
# RestingECG        918
# MaxHR             918
# ExerciseAngina    918
# Oldpeak           918
# ST_Slope          918
# HeartDisease      918
# dtype: int64

# %%
heart_df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
heart_df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
heart_df.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
heart_df.tail(10)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 908   63   M           ASY        140          187          0        LVH
# 909   63   F           ASY        124          197          0     Normal
# 910   41   M           ATA        120          157          0     Normal
# 911   59   M           ASY        164          176          1        LVH
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 908    144              Y      4.0       Up             1
# ...

# %%
stroke_df.tail(20)
# Out:
#          id  gender    age  hypertension  heart_disease ever_married  \
# 5090   4211    Male  26.00             0              0           No
# 5091   6369    Male  59.00             1              0          Yes
# 5092  56799    Male  76.00             0              0          Yes
# 5093  32235  Female  45.00             1              0          Yes
# 5094  28048    Male  13.00             0              0           No
# 5095  68598    Male   1.08             0              0           No
# 5096  41512    Male  57.00             0              0          Yes
# 5097  64520    Male  68.00             0              0          Yes
# 5098    579    Male   9.00             0              0           No
# 5099   7293    Male  40.00             0              0          Yes
# 5100  68398    Male  82.00             1              0          Yes
# 5101  36901  Female  45.00             0              0          Yes
# 5102  45010  Female  57.00             0              0          Yes
# ...

# %% [markdown]
#  # Drop unnecessary columns from the merged DataFrame.
#  # Add in the function to fill in the missing values in stroke
#  # Create a variable that will hold the non-null values

# %%
df = pd.DataFrame(stroke)
df.replace('N/A', 'na.nan', inplace=True)

# %%
df = pd.DataFrame(stroke)
df.replace('nan', 'na.nan', inplace=True)

# %%
df = pd.DataFrame(stroke)
df.replace('0', 'na.nan', inplace=True)

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
stroke_df.dropna()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
stroke_df.dropna(axis='index', how='any')
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
stroke_df.dropna(axis='index', how='all', subset=['bmi'])
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
heart_df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
heart_df.dropna(axis='index', how='any')
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart_df.columns.tolist()
# Out:
# ['Age',
#  'Sex',
#  'ChestPainType',
#  'RestingBP',
#  'Cholesterol',
#  'FastingBS',
#  'RestingECG',
#  'MaxHR',
#  'ExerciseAngina',
#  'Oldpeak',
#  'ST_Slope',
#  'HeartDisease']

# %%
stroke_df.columns.tolist()
# Out:
# ['id',
#  'gender',
#  'age',
#  'hypertension',
#  'heart_disease',
#  'ever_married',
#  'work_type',
#  'Residence_type',
#  'avg_glucose_level',
#  'bmi',
#  'smoking_status',
#  'stroke']

# %%
len(heart)
# Out:
# 918

# %%
len(stroke)
# Out:
# 5110

# %%
df.isna()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# ...

# %%
df.fillna(0)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
type(np.nan)
# Out:
# float

# %%
df['bmi'] = df['bmi'].astype(float)

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
cleaned_heart_df = pd.DataFrame(heart)
cleaned_heart_df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
cleaned_stroke_df = pd.DataFrame(stroke)
cleaned_stroke_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
from config import db_password
file_dir = ('./')
import config
from sqlalchemy import create_engine
import pymysql
import dbconfig
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/My_first_Project"

engine = create_engine(db_string)
stroke.to_sql(name='stroke', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32676\1033702695.py in <module>
# ----> 1 from config import db_password
#       2 file_dir = ('./')
#       3 import config
#       4 from sqlalchemy import create_engine
#       5 import pymysql
#
# ImportError: cannot import name 'db_password' from 'config' (c:\Bootcampgithub\My_first_Project\config.py)

# %%
from config import db_password
file_dir = ('./')
import config
from sqlalchemy import create_engine
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/My_first_Project"

engine = create_engine(db_string)
heart_df.to_sql(name='heart', con=engine)

# %%
# Add the code to create the connection to the PostgreSQL database, then add the movies_df DataFrame to a SQL database.
    # "postgres://[user]:[password]@[location]:[port]/[database]"
    db_string = f"postgresql://postgres:{db_password}@[location]/database_name"
    # Create the database engine
    engine = create_engine(db_string)
    # Save df to SQL table
    cleaned_titles_df.to_sql(name='titles', con=engine, if_exists='replace')
    credits_df.to_sql(name='credits', con=engine, if_exists='replace')

     # Create the path to your file directory and variables for the files.
     file_dir = ' #Path '
